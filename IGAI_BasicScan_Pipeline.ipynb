# %% [markdown]
# # Load Libraries & Functions

# %%
import os
path = os.getcwd() + '\\'
igai_initialize = path + 'IGAI_Initialize.ipynb'

# %run $igai_initialize
# Out:
# Libraries and functions loaded correctly 2021-01-25 19:15:04.602500

# %% [markdown]
# # Start Driver & Login

# %%
#account = "beautiful.flowers.and.plants"
#account = 'las.m.a.m.o'
#account = 'reboludeces'
account = '_rebocop'

# %%
driver = webdriver.Chrome(executable_path="C:\Program Files (x86)\Google\Chrome\Application\chromedriver.exe")
driver.maximize_window()
driver.implicitly_wait(10)

pwd = pd.read_csv(pwd_file)
pwdaccount = pwd[pwd.username == account].pwd.iloc[0]

do_Login(account,pwdaccount)

# %% [markdown]
# # PIPELINE: Extract Info VIP users

# %%
vip_users2 = list([ 'reboludeces'
                   , '_rebocop'
                   , 'beautiful.flowers.and.plants'
                   , 'rebolbear'
                   , 'danisure21'
                   , 'jav_rubin'
                   , 'seraspatetica'
                   , 'dramasdehonor'
                   , 'lavictoriabanks'
                   , 'danieljarque'
                   , 'influencerdemercadillo'
                   , 'tedejobonito'
                   , 'eduardography'
                   , 'davidpgalvez'
                   , 'dichoyhecho'
                   , 'dulceisma'
                   , 'juvat_vivere'
                   , 'aqavas'
                   , 'lalitogram'
                   , 'adri_gipe'
                   , 'byadri_gipe'
                   , 'marimontanafest'
                   , 'oviaska'
                   , 'frewtwojota'
                   , 'roma.ba'])

#vip_users2 = list(['goodluckshootinthemoon','matmazelmeli']) 


for username in vip_users2:
    print('EXTRACTING BASIC INFO OF @' + username.upper() )
    print('--------------------------------------------------------------------------------------------------------------')
    UserInfo(username)
    print('\n')
    time.sleep(1)

print('FINISHED ========================================================================================================')
# Out:
# EXTRACTING BASIC INFO OF @REBOLUDECES
# --------------------------------------------------------------------------------------------------------------
# Loaded file users_ext.csv with 1 records.
# Loaded file users.csv with 55079 records.
# Table users updated, now it has 55079 records.
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\users
# Removed csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\user_info_ext
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\vipuserstrk
#
#
# EXTRACTING BASIC INFO OF @_REBOCOP
# --------------------------------------------------------------------------------------------------------------
# Loaded file users_ext.csv with 1 records.
# Loaded file users.csv with 55079 records.
# Table users updated, now it has 55079 records.
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\users
# Removed csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\user_info_ext
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\vipuserstrk
#
#
# EXTRACTING BASIC INFO OF @BEAUTIFUL.FLOWERS.AND.PLANTS
# --------------------------------------------------------------------------------------------------------------
# Loaded file users_ext.csv with 1 records.
# Loaded file users.csv with 55079 records.
# Table users updated, now it has 55079 records.
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\users
# Removed csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\user_info_ext
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\vipuserstrk
#
#
# EXTRACTING BASIC INFO OF @REBOLBEAR
# --------------------------------------------------------------------------------------------------------------
# Loaded file users_ext.csv with 1 records.
# Loaded file users.csv with 55079 records.
# Table users updated, now it has 55079 records.
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\users
# Removed csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\user_info_ext
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\vipuserstrk
#
#
# EXTRACTING BASIC INFO OF @DANISURE21
# --------------------------------------------------------------------------------------------------------------
# Loaded file users_ext.csv with 1 records.
# Loaded file users.csv with 55079 records.
# Table users updated, now it has 55079 records.
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\users
# Removed csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\user_info_ext
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\vipuserstrk
#
#
# EXTRACTING BASIC INFO OF @JAV_RUBIN
# --------------------------------------------------------------------------------------------------------------
# Loaded file users_ext.csv with 1 records.
# Loaded file users.csv with 55079 records.
# Table users updated, now it has 55079 records.
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\users
# Removed csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\user_info_ext
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\vipuserstrk
#
#
# EXTRACTING BASIC INFO OF @SERASPATETICA
# --------------------------------------------------------------------------------------------------------------
# Loaded file users_ext.csv with 1 records.
# Loaded file users.csv with 55079 records.
# Table users updated, now it has 55079 records.
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\users
# Removed csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\user_info_ext
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\vipuserstrk
#
#
# EXTRACTING BASIC INFO OF @DRAMASDEHONOR
# --------------------------------------------------------------------------------------------------------------
# Loaded file users_ext.csv with 1 records.
# Loaded file users.csv with 55079 records.
# Table users updated, now it has 55079 records.
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\users
# Removed csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\user_info_ext
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\vipuserstrk
#
#
# EXTRACTING BASIC INFO OF @LAVICTORIABANKS
# --------------------------------------------------------------------------------------------------------------
# Loaded file users_ext.csv with 1 records.
# Loaded file users.csv with 55079 records.
# Table users updated, now it has 55079 records.
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\users
# Removed csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\user_info_ext
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\vipuserstrk
#
#
# EXTRACTING BASIC INFO OF @DANIELJARQUE
# --------------------------------------------------------------------------------------------------------------
# Loaded file users_ext.csv with 1 records.
# Loaded file users.csv with 55079 records.
# Table users updated, now it has 55079 records.
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\users
# Removed csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\user_info_ext
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\vipuserstrk
#
#
# EXTRACTING BASIC INFO OF @INFLUENCERDEMERCADILLO
# --------------------------------------------------------------------------------------------------------------
# Loaded file users_ext.csv with 1 records.
# Loaded file users.csv with 55079 records.
# Table users updated, now it has 55079 records.
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\users
# Removed csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\user_info_ext
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\vipuserstrk
#
#
# EXTRACTING BASIC INFO OF @TEDEJOBONITO
# --------------------------------------------------------------------------------------------------------------
# Loaded file users_ext.csv with 1 records.
# Loaded file users.csv with 55079 records.
# Table users updated, now it has 55079 records.
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\users
# Removed csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\user_info_ext
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\vipuserstrk
#
#
# EXTRACTING BASIC INFO OF @EDUARDOGRAPHY
# --------------------------------------------------------------------------------------------------------------
# Loaded file users_ext.csv with 1 records.
# Loaded file users.csv with 55079 records.
# Table users updated, now it has 55079 records.
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\users
# Removed csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\user_info_ext
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\vipuserstrk
#
#
# EXTRACTING BASIC INFO OF @DAVIDPGALVEZ
# --------------------------------------------------------------------------------------------------------------
# Loaded file users_ext.csv with 1 records.
# Loaded file users.csv with 55079 records.
# Table users updated, now it has 55079 records.
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\users
# Removed csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\user_info_ext
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\vipuserstrk
#
#
# EXTRACTING BASIC INFO OF @DICHOYHECHO
# --------------------------------------------------------------------------------------------------------------
# Loaded file users_ext.csv with 1 records.
# Loaded file users.csv with 55079 records.
# Table users updated, now it has 55079 records.
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\users
# Removed csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\user_info_ext
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\vipuserstrk
#
#
# EXTRACTING BASIC INFO OF @DULCEISMA
# --------------------------------------------------------------------------------------------------------------
# Loaded file users_ext.csv with 1 records.
# Loaded file users.csv with 55079 records.
# Table users updated, now it has 55079 records.
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\users
# Removed csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\user_info_ext
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\vipuserstrk
#
#
# EXTRACTING BASIC INFO OF @JUVAT_VIVERE
# --------------------------------------------------------------------------------------------------------------
# Loaded file users_ext.csv with 1 records.
# Loaded file users.csv with 55079 records.
# Table users updated, now it has 55079 records.
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\users
# Removed csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\user_info_ext
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\vipuserstrk
#
#
# EXTRACTING BASIC INFO OF @AQAVAS
# --------------------------------------------------------------------------------------------------------------
# Loaded file users_ext.csv with 1 records.
# Loaded file users.csv with 55079 records.
# Table users updated, now it has 55079 records.
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\users
# Removed csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\user_info_ext
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\vipuserstrk
#
#
# EXTRACTING BASIC INFO OF @LALITOGRAM
# --------------------------------------------------------------------------------------------------------------
# Loaded file users_ext.csv with 1 records.
# Loaded file users.csv with 55079 records.
# Table users updated, now it has 55079 records.
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\users
# Removed csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\user_info_ext
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\vipuserstrk
#
#
# EXTRACTING BASIC INFO OF @ADRI_GIPE
# --------------------------------------------------------------------------------------------------------------
# Loaded file users_ext.csv with 1 records.
# Loaded file users.csv with 55079 records.
# Table users updated, now it has 55079 records.
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\users
# Removed csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\user_info_ext
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\vipuserstrk
#
#
# EXTRACTING BASIC INFO OF @BYADRI_GIPE
# --------------------------------------------------------------------------------------------------------------
# Loaded file users_ext.csv with 1 records.
# Loaded file users.csv with 55079 records.
# Table users updated, now it has 55079 records.
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\users
# Removed csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\user_info_ext
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\vipuserstrk
#
#
# EXTRACTING BASIC INFO OF @MARIMONTANAFEST
# --------------------------------------------------------------------------------------------------------------
# Loaded file users_ext.csv with 1 records.
# Loaded file users.csv with 55079 records.
# Table users updated, now it has 55079 records.
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\users
# Removed csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\user_info_ext
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\vipuserstrk
#
#
# EXTRACTING BASIC INFO OF @OVIASKA
# --------------------------------------------------------------------------------------------------------------
# Loaded file users_ext.csv with 1 records.
# Loaded file users.csv with 55079 records.
# Table users updated, now it has 55079 records.
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\users
# Removed csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\user_info_ext
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\vipuserstrk
#
#
# EXTRACTING BASIC INFO OF @FREWTWOJOTA
# --------------------------------------------------------------------------------------------------------------
# Loaded file users_ext.csv with 1 records.
# Loaded file users.csv with 55079 records.
# Table users updated, now it has 55079 records.
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\users
# Removed csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\user_info_ext
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\vipuserstrk
#
#
# EXTRACTING BASIC INFO OF @ROMA.BA
# --------------------------------------------------------------------------------------------------------------
# Loaded file users_ext.csv with 1 records.
# Loaded file users.csv with 55079 records.
# Table users updated, now it has 55079 records.
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\users
# Removed csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\user_info_ext
# Saved csv file: C:\Users\DavidRebollo\0.InstagramScrapping\dev\vipuserstrk
#
#
# FINISHED ========================================================================================================
